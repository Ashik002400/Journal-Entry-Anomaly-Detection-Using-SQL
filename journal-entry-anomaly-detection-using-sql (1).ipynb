# %%
# !pip install duckdb
import duckdb
import pandas as pd


try:
   
    df = pd.read_csv('/kaggle/input/journal-entries/journal_entry_anomalies.csv')
    
   
    print("--- Data Loading ---")
    print("Successfully loaded CSV. Columns are:", df.columns.tolist())
    
    # Register the pandas DataFrame as a virtual table in DuckDB
    duckdb.register("journal_entries", df)
    
except FileNotFoundError:
    print("--- Data Loading Failed ---")
    print("Error: The file '/kaggle/input/journal-entries/journal_entry_anomalies.csv' was not found.")
    print("Please ensure the file path is correct.")
   
    exit()

print("\n" + "="*50 + "\n") # Separator for clarity



queries_to_run = [
    {
        "title": "Query 1: Top 10 Highest Value Transactions",
        "sql": """
            SELECT *
            FROM journal_entries
            ORDER BY Amount DESC
            LIMIT 10;
        """
    },
    {
        "title": "Query 2: Transactions Posted on a Weekend",
        "sql": """
            SELECT *
            FROM journal_entries
            WHERE DAYOFWEEK(strptime(Date, '%d-%m-%Y')) IN (0, 6); -- Sunday=0, Saturday=6
        """
    },
    {
        "title": "Query 3: Top 10 Users by Number of Entries Made",
        "sql": """
            SELECT
    Created_By,
    COUNT(*) AS EntryCount
FROM
    journal_entries
GROUP BY
    Created_By
ORDER BY
    EntryCount DESC
LIMIT 10;
        """
    },
    {
        "title": "Query 4: Frequently Recurring Transaction Amounts (Potential Automation/Error)",
        "sql": """
            SELECT
                Amount,
                COUNT(*) AS Frequency
            FROM journal_entries
            GROUP BY Amount
            HAVING COUNT(*) > 5
            ORDER BY Frequency DESC;
        """
    },
    {
        "title": "Query 5: Entries with Missing or Blank Descriptions",
        "sql": """
            SELECT *
            FROM journal_entries
            WHERE Description IS NULL OR TRIM(Description) = '';
        """
    },
    {
       # 1. Define 'Write-off' and 'Suspense' as sensitive accounts.
# 2. Assume only 'user1' and 'user5' are authorized to APPROVE transactions in these accounts.
# 3. Find all entries in these accounts that were approved by anyone else (user2, user3, user4).

  "title": "Query 6: Unauthorized Approvals on Sensitive Accounts",
        "sql": """
            SELECT Entry_ID, Date, Account_Name, Amount, Created_By, Approved_By
            FROM journal_entries
            WHERE Account_Name IN ('Write-off', 'Suspense')
              AND Approved_By NOT IN ('user1', 'user5');
              """
    },
    {
        "title": "Query 7: Transactions with Suspicious Dates (Future or Very Old)",
        "sql": """
            SELECT *
            FROM journal_entries
            WHERE
                strptime(Date, '%d-%m-%Y') > CURRENT_DATE OR strptime(Date, '%d-%m-%Y') < '2020-01-01';
        """
    },
    {
        "title": "Query 8: Benford's Law Analysis (First Digit Distribution)",
        "sql": """
            SELECT
                SUBSTRING(CAST(Amount AS VARCHAR), 1, 1) AS FirstDigit,
                COUNT(*) AS Count,
                COUNT(*) * 100.0 / (SELECT COUNT(*) FROM journal_entries WHERE Amount > 0) AS Percentage
            FROM journal_entries
            WHERE Amount > 0
            GROUP BY FirstDigit
            ORDER BY FirstDigit;
        """
    },
    {
        "title": "Query 9: Analysis of Round Number Transactions",
        "sql": """
            SELECT *
            FROM journal_entries
            WHERE Amount % 100 = 0 AND Amount > 0
            ORDER BY Amount DESC;
        """
    },
    {
        "title": "Query 10: Critical Control Failure - Entries Approved by the Same User Who Created Them",
        "sql": """
            SELECT *
            FROM journal_entries
            WHERE Created_By = Approved_By;
        """
    }
]


for query in queries_to_run:
    print(f"--- {query['title']} ---")
    try:
        # Execute the query and fetch the result as a pandas DataFrame
        result_df = duckdb.query(query['sql']).to_df()
        
        # Display the result
        if result_df.empty:
            print("No results found for this query.")
        else:
            print(result_df)
            
    except Exception as e:
        print(f"An error occurred while running the query: {e}")
        
    print("\n" + "="*50 + "\n") # Separator for clarity



print("--- Final Analysis: Top 15 Entries with Highest Anomaly Scores ---")

flags_query = """
SELECT
    *,
    -- Flag for High Value
    (CASE WHEN Amount > 100000 THEN 1 ELSE 0 END) +
    -- Flag for Weekend Entry
    (CASE WHEN DAYOFWEEK(strptime(Date, '%d-%m-%Y')) IN (0, 6) THEN 1 ELSE 0 END) +
    -- Flag for Empty Description
    (CASE WHEN Description IS NULL OR TRIM(Description) = '' THEN 1 ELSE 0 END) +
    -- Flag for Round Number
    (CASE WHEN Amount % 100 = 0 AND Amount > 0 THEN 1 ELSE 0 END) +
    -- Flag for Self-Approval
    (CASE WHEN Created_By = Approved_By THEN 1 ELSE 0 END)
    AS AnomalyScore
FROM
    journal_entries;
"""

try:
    anomalies_df = duckdb.query(flags_query).to_df()
    sorted_anomalies = anomalies_df.sort_values(by='AnomalyScore', ascending=False)
    final_report_df = sorted_anomalies.reset_index(drop=True)
   
    print(final_report_df.head(15))

except Exception as e:
    print(f"An error occurred while calculating anomaly scores: {e}")
# Out:
# Requirement already satisfied: duckdb in /usr/local/lib/python3.11/dist-packages (1.2.2)
# --- Data Loading ---
# Successfully loaded CSV. Columns are: ['Entry_ID', 'Date', 'Time', 'Account_Name', 'Amount', 'Description', 'Created_By', 'Approved_By', 'Label_Anomaly']
#
# ==================================================
#
# --- Query 1: Top 10 Highest Value Transactions ---
#    Entry_ID        Date      Time         Account_Name  Amount  \
# 0        43  06-05-2023  08:57:58                 Loan   49999
# 1       183  15-03-2023  02:41:55                 Loan   49999
# 2        45  30-06-2023  13:35:00                 Cash   49999
# 3       188  11-06-2023  20:21:04             Suspense   49999
# 4       189  18-06-2023  19:55:09             Suspense   49999
# 5       179  27-01-2023  04:16:12              Revenue   49921
# 6        30  13-01-2023  20:34:53                 Cash   49485
# 7       196  04-04-2023  21:46:15  Accounts Receivable   49408
# 8       104  06-02-2023  02:03:10                 Loan   49183
# 9       126  02-03-2023  20:43:58             Suspense   49040
#
#         Description Created_By Approved_By  Label_Anomaly
# 0              None      user3       user1              1
# 1        Adjustment      user4       user4              1
# 2    Invoice issued      user5       user1              1
# 3              None      user3       user3              1
# 4    Invoice issued      user3       user3              1
# 5              None      user1       user2              1
# 6              None      user2       user2              1
# 7         Write-off      user4       user2              1
# 8              None      user5       user3              1
# 9  Payment received      user4       user1              1
#
# ==================================================
#
# --- Query 2: Transactions Posted on a Weekend ---
#     Entry_ID        Date      Time         Account_Name  Amount  \
# 55       180  10-06-2023  15:29:48            Inventory   29519
# 56       190  17-06-2023  22:42:25              Revenue    5652
# 57       198  29-04-2023  09:49:24            Inventory   10720
#
#          Description Created_By Approved_By  Label_Anomaly
# 0   Payment received      user2       user1              1
# 1         Adjustment      user1       user5              0
# 2          Write-off      user4       user5              1
# 3               None      user1       user4              1
# 4           Transfer      user4       user1              1
# 5           Transfer      user2       user3              1
# 6           Transfer      user2       user3              1
# 7         Adjustment      user1       user1              1
# 8               None      user1       user5              1
# 9         Adjustment      user3       user2              1
# 10          Transfer      user1       user2              1
# 11        Adjustment      user5       user4              1
# 12          Transfer      user1       user1              1
# 13              None      user5       user1              1
# 14        Adjustment      user4       user4              1
# 15        Adjustment      user1       user5              1
# 16              None      user5       user2              1
# 17              None      user3       user1              1
# 18         Write-off      user4       user5              1
# 19          Transfer      user2       user1              1
# 20    Invoice issued      user5       user3              1
# 21  Payment received      user3       user4              1
# 22              None      user2       user3              1
# 23         Write-off      user1       user5              0
# 24              None      user3       user3              1
# 25    Invoice issued      user3       user3              1
# 26  Payment received      user5       user1              0
# 27          Transfer      user2       user3              0
# 28         Write-off      user3       user1              1
# 29    Invoice issued      user2       user5              1
# 30          Transfer      user1       user3              1
# 31        Adjustment      user2       user5              1
# 32    Invoice issued      user3       user2              1
# 33              None      user1       user1              1
# 34    Invoice issued      user4       user1              0
# 35         Write-off      user5       user2              1
# 36         Write-off      user3       user5              1
# 37              None      user3       user1              1
# 38              None      user3       user3              1
# 39              None      user4       user2              1
# 40              None      user4       user2              1
# 41        Adjustment      user1       user2              0
# 42          Transfer      user4       user2              1
# 43              None      user3       user2              1
# 44         Write-off      user2       user3              1
# 45    Invoice issued      user2       user3              0
# 46         Write-off      user4       user1              1
# 47         Write-off      user2       user4              1
# 48    Invoice issued      user5       user4              1
# 49          Transfer      user2       user1              1
# 50         Write-off      user3       user1              1
# 51              None      user4       user1              1
# 52        Adjustment      user2       user4              1
# 53              None      user5       user4              1
# 54              None      user2       user1              1
# 55         Write-off      user5       user5              1
# 56          Transfer      user5       user4              1
# 57              None      user2       user5              1
#
# ==================================================
#
# --- Query 3: Top 10 Users by Number of Entries Made ---
#   Created_By  EntryCount
# 0      user5          43
# 1      user2          41
# 2      user4          41
# 3      user3          40
# 4      user1          35
#
# ==================================================
#
# --- Query 4: Frequently Recurring Transaction Amounts (Potential Automation/Error) ---
#    Amount  Frequency
# 0   19999          6
#
# ==================================================
#
# --- Query 5: Entries with Missing or Blank Descriptions ---
#     Entry_ID        Date      Time         Account_Name  Amount Description  \
# 0          3  24-05-2023  06:45:41            Write-off   14546        None
# 1          4  02-01-2023  05:44:27             Suspense   14210        None
# 2          5  24-01-2023  12:06:22                 Loan   17435        None
# 3         26  19-05-2023  04:46:59            Inventory   16025        None
# 4         27  18-02-2023  03:06:42  Accounts Receivable   27041        None
# 5         29  25-04-2023  04:27:11             Suspense    5040        None
# 6         30  13-01-2023  20:34:53                 Cash   49485        None
# 58       195  16-02-2023  22:49:39                 Loan   47363        None
# 59       198  29-04-2023  09:49:24            Inventory   10720        None
#
#    Created_By Approved_By  Label_Anomaly
# 0       user5       user3              1
# 1       user3       user1              1
# 2       user1       user4              1
# 3       user4       user4              1
# 4       user1       user1              1
# 5       user5       user1              1
# 6       user2       user2              1
# 7       user3       user1              1
# 8       user4       user5              1
# 9       user1       user4              1
# 10      user3       user3              1
# 11      user3       user4              1
# 12      user4       user4              1
# 13      user1       user4              1
# 14      user2       user2              1
# 15      user4       user2              1
# 16      user2       user4              1
# 17      user2       user2              1
# 18      user4       user2              1
# 19      user3       user2              1
# 20      user1       user1              1
# 21      user1       user5              1
# 22      user2       user1              1
# 23      user5       user1              1
# 24      user4       user4              1
# 25      user3       user2              1
# 26      user5       user3              1
# 27      user4       user3              1
# 28      user4       user1              1
# 29      user5       user3              1
# 30      user3       user5              1
# 31      user5       user1              1
# 32      user5       user1              1
# 33      user1       user3              1
# 34      user2       user4              1
# 35      user5       user4              1
# 36      user5       user2              1
# 37      user5       user3              1
# 38      user3       user1              1
# 39      user3       user2              1
# 40      user2       user1              1
# 41      user3       user3              1
# 42      user1       user5              1
# 43      user4       user3              1
# 44      user1       user1              1
# 45      user3       user1              1
# 46      user2       user5              1
# 47      user1       user1              1
# 48      user1       user5              1
# 49      user4       user1              1
# 50      user2       user5              1
# 51      user5       user1              1
# 52      user2       user3              1
# 53      user5       user4              1
# 54      user2       user1              1
# 55      user1       user2              1
# 56      user3       user3              1
# 57      user2       user2              1
# 58      user1       user4              1
# 59      user2       user5              1
#
# ==================================================
#
# --- Query 6: Unauthorized Approvals on Sensitive Accounts ---
#     Entry_ID        Date Account_Name  Amount Created_By Approved_By
# 0          3  24-05-2023    Write-off   14546      user5       user3
# 1         18  28-01-2023    Write-off   13135      user3       user2
# 2         56  20-06-2023    Write-off   47269      user5       user3
# 3         57  20-06-2023    Write-off    8441      user4       user4
# 4         63  17-04-2023    Write-off   32499      user2       user2
# 5         67  21-05-2023    Write-off   29595      user2       user3
# 6         72  10-04-2023    Write-off   39634      user4       user2
# 7         92  31-01-2023    Write-off   14280      user4       user3
# 8        102  16-03-2023    Write-off   29855      user2       user3
# 9        108  11-01-2023    Write-off   18329      user5       user4
# 10       121  01-03-2023    Write-off   25084      user2       user4
# 11       124  28-03-2023    Write-off   19999      user5       user4
# 12       148  27-04-2023    Write-off    1499      user3       user2
# 13        39  10-05-2023     Suspense   16109      user3       user2
# 14        51  07-01-2023     Suspense    4649      user3       user3
# 15        61  12-05-2023     Suspense    9999      user3       user2
# 16        66  20-06-2023     Suspense   29104      user5       user4
# 17        68  14-05-2023     Suspense   46862      user2       user3
# 18        83  18-04-2023     Suspense   30229      user2       user4
# 19        84  15-02-2023     Suspense   35369      user4       user4
# 20        85  22-04-2023     Suspense    5779      user4       user2
# 21        91  01-04-2023     Suspense    8007      user2       user3
# 22       105  23-04-2023     Suspense   17941      user5       user4
# 23       109  12-06-2023     Suspense   21140      user1       user2
# 24       120  20-05-2023     Suspense   45811      user5       user4
# 25       122  10-01-2023     Suspense   28955      user5       user4
# 26       130  06-02-2023     Suspense   43802      user4       user3
# 27       156  05-06-2023     Suspense   38462      user3       user4
# 28       163  28-01-2023     Suspense   18356      user2       user4
# 29       165  16-02-2023     Suspense   23104      user2       user2
# 30       188  11-06-2023     Suspense   49999      user3       user3
# 31       189  18-06-2023     Suspense   49999      user3       user3
# 32       192  15-06-2023     Suspense   19999      user2       user3
#
# ==================================================
#
# --- Query 7: Transactions with Suspicious Dates (Future or Very Old) ---
# No results found for this query.
#
# ==================================================
#
# --- Query 8: Benford's Law Analysis (First Digit Distribution) ---
#   FirstDigit  Count  Percentage
# 0          1     54        27.0
# 1          2     45        22.5
# 2          3     38        19.0
# 3          4     41        20.5
# 4          5      4         2.0
# 5          6      2         1.0
# 6          7      4         2.0
# 7          8      6         3.0
# 8          9      6         3.0
#
# ==================================================
#
# --- Query 9: Analysis of Round Number Transactions ---
# No results found for this query.
#
# ==================================================
#
# --- Query 10: Critical Control Failure - Entries Approved by the Same User Who Created Them ---
#     Entry_ID        Date      Time         Account_Name  Amount  \
# 0          9  29-06-2023  21:41:04            Inventory   35105
# 1         13  18-05-2023  08:47:37  Accounts Receivable   26275
# 2         19  19-05-2023  16:58:00            Inventory    1376
# 3         21  17-05-2023  04:08:42  Accounts Receivable   10921
# 4         26  19-05-2023  04:46:59            Inventory   16025
# 5         27  18-02-2023  03:06:42  Accounts Receivable   27041
# 6         30  13-01-2023  20:34:53                 Cash   49485
# 7         36  02-06-2023  01:39:05  Accounts Receivable   37142
# 8         50  10-01-2023  15:14:12                 Loan   23015
# 9         51  07-01-2023  21:12:25             Suspense    4649
# 10        57  20-06-2023  13:20:25            Write-off    8441
# 11        59  15-03-2023  06:27:50            Inventory   21218
# 12        63  17-04-2023  20:36:12            Write-off   32499
# 13        69  27-03-2023  10:57:34                 Cash   15255
# 14        70  17-01-2023  13:26:21            Inventory    4180
# 15        71  30-05-2023  22:01:54                 Loan   31359
# 16        74  30-04-2023  04:39:34                 Cash   38890
# 17        77  05-01-2023  23:34:03             Suspense    4596
# 18        84  15-02-2023  23:33:41             Suspense   35369
# 19       106  23-04-2023  02:38:02  Accounts Receivable   39664
# 20       112  18-06-2023  17:29:26                 Cash   23809
# 21       137  17-03-2023  10:47:26              Revenue   35450
# 22       140  04-04-2023  02:50:25                 Cash    8199
# 23       143  16-06-2023  13:07:08                 Cash   20046
# 24       149  02-02-2023  18:13:04                 Loan   13676
# 25       152  24-03-2023  00:11:16                 Cash   27688
# 26       154  12-01-2023  23:50:58                 Loan   19867
# 27       165  16-02-2023  08:44:48             Suspense   23104
# 28       167  07-04-2023  13:29:21              Revenue   47390
# 29       178  11-05-2023  20:07:33            Inventory   22996
# 30       180  10-06-2023  15:29:48            Inventory   29519
# 31       181  24-03-2023  20:20:09  Accounts Receivable   19999
# 32       183  15-03-2023  02:41:55                 Loan   49999
# 33       186  15-06-2023  05:02:15            Write-off   28897
# 34       188  11-06-2023  20:21:04             Suspense   49999
# 35       189  18-06-2023  19:55:09             Suspense   49999
# 36       193  05-05-2023  06:14:08              Revenue    9999
# 37       194  10-01-2023  21:21:56                 Loan   39241
#
#          Description Created_By Approved_By  Label_Anomaly
# 0          Write-off      user2       user2              1
# 1           Transfer      user2       user2              1
# 2   Payment received      user3       user3              1
# 3           Transfer      user5       user5              1
# 4               None      user4       user4              1
# 5               None      user1       user1              1
# 6               None      user2       user2              1
# 7         Adjustment      user3       user3              1
# 8           Transfer      user2       user2              1
# 9               None      user3       user3              1
# 10    Invoice issued      user4       user4              1
# 11              None      user4       user4              1
# 12              None      user2       user2              1
# 13              None      user2       user2              1
# 14    Invoice issued      user4       user4              1
# 15  Payment received      user3       user3              1
# 16        Adjustment      user1       user1              1
# 17              None      user1       user1              1
# 18              None      user4       user4              1
# 19          Transfer      user1       user1              1
# 20        Adjustment      user4       user4              1
# 21          Transfer      user5       user5              1
# 22              None      user3       user3              1
# 23              None      user1       user1              1
# 24        Adjustment      user2       user2              1
# 25        Adjustment      user1       user1              1
# 26              None      user1       user1              1
# 27  Payment received      user2       user2              1
# 28          Transfer      user5       user5              1
# 29          Transfer      user2       user2              1
# 30         Write-off      user5       user5              1
# 31         Write-off      user3       user3              1
# 32        Adjustment      user4       user4              1
# 33        Adjustment      user5       user5              1
# 34              None      user3       user3              1
# 35    Invoice issued      user3       user3              1
# 36        Adjustment      user5       user5              1
# 37              None      user2       user2              1
#
# ==================================================
#
# --- Final Analysis: Top 15 Entries with Highest Anomaly Scores ---
#     Entry_ID        Date      Time         Account_Name  Amount Description  \
# 0         27  18-02-2023  03:06:42  Accounts Receivable   27041        None
# 1        188  11-06-2023  20:21:04             Suspense   49999        None
# 2         51  07-01-2023  21:12:25             Suspense    4649        None
# 3        143  16-06-2023  13:07:08                 Cash   20046        None
# 4         30  13-01-2023  20:34:53                 Cash   49485        None
# 5         43  06-05-2023  08:57:58                 Loan   49999        None
# 6        180  10-06-2023  15:29:48            Inventory   29519   Write-off
# 7         49  16-04-2023  21:55:47                 Loan   10533        None
# 8        177  21-01-2023  12:55:19            Write-off   21927        None
# 9         59  15-03-2023  06:27:50            Inventory   21218        None
# 10        63  17-04-2023  20:36:12            Write-off   32499        None
# 11        64  17-06-2023  22:00:57                 Loan    7085        None
# 12       133  28-05-2023  09:44:18                 Cash   43237        None
# 13        69  27-03-2023  10:57:34                 Cash   15255        None
# 14        73  11-03-2023  13:31:01  Accounts Receivable   44608        None
#
#    Created_By Approved_By  Label_Anomaly  AnomalyScore
# 0       user1       user1              1             3
# 1       user3       user3              1             3
# 2       user3       user3              1             3
# 3       user1       user1              1             2
# 4       user2       user2              1             2
# 5       user3       user1              1             2
# 6       user5       user5              1             2
# 7       user1       user4              1             2
# 8       user2       user1              1             2
# 9       user4       user4              1             2
# 10      user2       user2              1             2
# 11      user4       user2              1             2
# 12      user3       user1              1             2
# 13      user2       user2              1             2
# 14      user4       user2              1             2
